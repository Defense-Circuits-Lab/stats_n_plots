# %% [raw]
# ---
# description: This module contains all functions to compute the relevant statistics.
# output-file: stats.html
# title: stats
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| include: false
from nbdev.showdoc import *

# %%
#|output: asis
#| echo: false
show_doc(StatisticalTest)
# Out:
# ---
#
# ### StatisticalTest
#
# >      StatisticalTest ()
#
# Helper class that provides a standard way to create an ABC using
# inheritance.

# %%
#|output: asis
#| echo: false
show_doc(OneSampleStats)
# Out:
# ---
#
# ### OneSampleStats
#
# >      OneSampleStats ()
#
# Helper class that provides a standard way to create an ABC using
# inheritance.

# %%
#|output: asis
#| echo: false
show_doc(MultipleIndependentSamplesStats)
# Out:
# ---
#
# ### MultipleIndependentSamplesStats
#
# >      MultipleIndependentSamplesStats ()
#
# Helper class that provides a standard way to create an ABC using
# inheritance.

# %%
#|output: asis
#| echo: false
show_doc(MixedModelANOVAStats)
# Out:
# ---
#
# ### MixedModelANOVAStats
#
# >      MixedModelANOVAStats ()
#
# Helper class that provides a standard way to create an ABC using
# inheritance.

# %%
#|output: asis
#| echo: false
show_doc(MultipleDependentSamplesStats)
# Out:
# ---
#
# ### MultipleDependentSamplesStats
#
# >      MultipleDependentSamplesStats ()
#
# Helper class that provides a standard way to create an ABC using
# inheritance.
