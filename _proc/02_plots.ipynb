# %% [raw]
# ---
# description: This module contains all functions to plot the data and annotate the
#   results of the statistical analyses.
# output-file: plots.html
# title: plots
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| include: false
from nbdev.showdoc import *

# %%
#|output: asis
#| echo: false
show_doc(sort_by_third)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/stats_n_plots/tree/master/blob/master/stats_n_plots/plots.py#L19){target="_blank" style="float:right; font-size:smaller"}
#
# ### sort_by_third
#
# >      sort_by_third (e)

# %%
#|output: asis
#| echo: false
show_doc(PlotHandler)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/stats_n_plots/tree/master/blob/master/stats_n_plots/plots.py#L23){target="_blank" style="float:right; font-size:smaller"}
#
# ### PlotHandler
#
# >      PlotHandler ()
#
# Helper class that provides a standard way to create an ABC using
# inheritance.

# %%
#|output: asis
#| echo: false
show_doc(OneSamplePlots)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/stats_n_plots/tree/master/blob/master/stats_n_plots/plots.py#L122){target="_blank" style="float:right; font-size:smaller"}
#
# ### OneSamplePlots
#
# >      OneSamplePlots ()
#
# Helper class that provides a standard way to create an ABC using
# inheritance.

# %%
#|output: asis
#| echo: false
show_doc(MultipleIndependentSamplesPlots)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/stats_n_plots/tree/master/blob/master/stats_n_plots/plots.py#L181){target="_blank" style="float:right; font-size:smaller"}
#
# ### MultipleIndependentSamplesPlots
#
# >      MultipleIndependentSamplesPlots ()
#
# Helper class that provides a standard way to create an ABC using
# inheritance.

# %%
#|output: asis
#| echo: false
show_doc(MixedModelANOVAPlots)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/stats_n_plots/tree/master/blob/master/stats_n_plots/plots.py#L245){target="_blank" style="float:right; font-size:smaller"}
#
# ### MixedModelANOVAPlots
#
# >      MixedModelANOVAPlots ()
#
# Helper class that provides a standard way to create an ABC using
# inheritance.

# %%
#|output: asis
#| echo: false
show_doc(MultipleDependentSamplesPlots)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/stats_n_plots/tree/master/blob/master/stats_n_plots/plots.py#L414){target="_blank" style="float:right; font-size:smaller"}
#
# ### MultipleDependentSamplesPlots
#
# >      MultipleDependentSamplesPlots ()
#
# Helper class that provides a standard way to create an ABC using
# inheritance.
