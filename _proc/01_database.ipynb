# %% [raw]
# ---
# description: This module is used to collect, maintain, and export all relevant information
#   (= the _database_).
# output-file: database.html
# title: database
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| include: false
from nbdev.showdoc import *

# %%
#|output: asis
#| echo: false
show_doc(Configs)
# Out:
# ---
#
# ### Configs
#
# >      Configs ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#|output: asis
#| echo: false
show_doc(Database)
# Out:
# ---
#
# ### Database
#
# >      Database ()
#
# Initialize self.  See help(type(self)) for accurate signature.
