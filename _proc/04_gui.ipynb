# %% [raw]
# ---
# description: This module creates a GUI based on ipywidgets that allows the use of
#   dcl_stats_n_plots with little to no coding expertise.
# output-file: gui.html
# title: gui
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| include: false
from nbdev.showdoc import *

# %%
#|output: asis
#| echo: false
show_doc(launch_gui)
# Out:
# ---
#
# [source](https://github.com/DSegebarth/dcl_stats_n_plots/tree/master/blob/master/dcl_stats_n_plots/gui.py#L26){target="_blank" style="float:right; font-size:smaller"}
#
# ### launch_gui
#
# >      launch_gui ()

# %%
#|output: asis
#| echo: false
show_doc(GUI)
# Out:
# ---
#
# [source](https://github.com/DSegebarth/dcl_stats_n_plots/tree/master/blob/master/dcl_stats_n_plots/gui.py#L30){target="_blank" style="float:right; font-size:smaller"}
#
# ### GUI
#
# >      GUI ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#|output: asis
#| echo: false
show_doc(PlainTab)
# Out:
# ---
#
# [source](https://github.com/DSegebarth/dcl_stats_n_plots/tree/master/blob/master/dcl_stats_n_plots/gui.py#L75){target="_blank" style="float:right; font-size:smaller"}
#
# ### PlainTab
#
# >      PlainTab (gui:__main__.GUI)
#
# Helper class that provides a standard way to create an ABC using
# inheritance.

# %%
#|output: asis
#| echo: false
show_doc(StatisticsTab)
# Out:
# ---
#
# [source](https://github.com/DSegebarth/dcl_stats_n_plots/tree/master/blob/master/dcl_stats_n_plots/gui.py#L87){target="_blank" style="float:right; font-size:smaller"}
#
# ### StatisticsTab
#
# >      StatisticsTab (gui:__main__.GUI)
#
# Helper class that provides a standard way to create an ABC using
# inheritance.

# %%
#|output: asis
#| echo: false
show_doc(PlotTab)
# Out:
# ---
#
# [source](https://github.com/DSegebarth/dcl_stats_n_plots/tree/master/blob/master/dcl_stats_n_plots/gui.py#L131){target="_blank" style="float:right; font-size:smaller"}
#
# ### PlotTab
#
# >      PlotTab (gui:__main__.GUI)
#
# Helper class that provides a standard way to create an ABC using
# inheritance.

# %%
#|output: asis
#| echo: false
show_doc(ConfigsTab)
# Out:
# ---
#
# [source](https://github.com/DSegebarth/dcl_stats_n_plots/tree/master/blob/master/dcl_stats_n_plots/gui.py#L184){target="_blank" style="float:right; font-size:smaller"}
#
# ### ConfigsTab
#
# >      ConfigsTab (gui:__main__.GUI)
#
# Helper class that provides a standard way to create an ABC using
# inheritance.

# %%
#| include: false
launch_gui()
