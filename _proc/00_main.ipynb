# %% [raw]
# ---
# description: This module represents the core of the `stats_n_plots` package.
# output-file: main.html
# title: main
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| include: false
from nbdev.showdoc import *

# %%
#|output: asis
#| echo: false
show_doc(Session)
# Out:
# ---
#
# ### Session
#
# >      Session ()
#
# Initialize self.  See help(type(self)) for accurate signature.
